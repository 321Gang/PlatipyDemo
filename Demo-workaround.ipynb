# %%
import SimpleITK as sitk
import glob
from platipy.imaging.tests.data import get_lung_nifti
from platipy.imaging import ImageVisualiser
from platipy.imaging.registration.linear import linear_registration
from platipy.imaging.registration.utils import apply_transform

# %%
img_ct_lung_5 = sitk.ReadImage("./PRHGD5257_LUNG/IMAGES/PRHGD5257_LUNG_0_CT_NON_CONTRAST_CHEST_5.nii.gz")
img_ct_lung_10 = sitk.ReadImage("./PRHGD5257_LUNG/IMAGES/PRHGD5257_LUNG_1_CT_NON_CONTRAST_CHEST_10.nii.gz")

# %%
img_ct, tfm = linear_registration(
    img_ct_lung_5,
    img_ct_lung_10,
    shrink_factors=[8],
    smooth_sigmas=[0],
    reg_method='rigid'
)

# %%
# Out:
# 2021-08-29 12:15:42.789 | DEBUG    | platipy.imaging.tests.data:get_lung_nifti:63 - Output directory exists, stopping. data\nifti\lung

# %%
input_directory = WindowsPath()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-6e823cf78552> in <module>
# ----> 1 input_directory = WindowsPath()
#
# NameError: name 'WindowsPath' is not defined

# %%
contours
# Out:
# {'100_TRIAL_2': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C05C847E10> >,
#  '4TH_RIB': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C05B2F83F0> >,
#  '5TH_RIB': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C05B2F87E0> >,
#  '6TH_RIB': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C05C818390> >,
#  '98_TRIAL_2': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C0001BE6C0> >,
#  'CARINA': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C06604B8D0> >,
#  'CHESTWALL': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C06604BBD0> >,
#  'CHEST_WALL': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C06604BCF0> >,
#  'CONTOUR_CHECK': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C06604BD20> >,
#  'EXTERNAL': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C06604BD80> >,
#  'EXTERNAL_5MM': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C06604BE10> >,
#  'EXTERNAL_PTV_2CM': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C06604BE70> >,
#  'GREAT_VESSELS': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C06604BED0> >,
#  'GTVP': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C0486A1C00> >,
#  'HEART': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C00023C210> >,
#  'ITV': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C00023C270> >,
#  'LUNGS_ITV': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C00023C2D0> >,
#  'LUNG_L': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C00023C330> >,
#  'LUNG_R': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C00023C390> >,
#  'OESOPHAGUS': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C00023C3F0> >,
#  'PROXBRONCHI': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C00023C450> >,
#  'PTV4800': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C00023C4B0> >,
#  'PTV4800_EXCL_RIB3MM': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C00023C510> >,
#  'PTV_2CM': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C00023C570> >,
#  'PTV_2CMRING': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C00023C5D0> >,
#  'RIBS': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C00023C630> >,
#  'RIBS_3MM': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C00023C690> >,
#  'SKIN': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C00023C6F0> >,
#  'SPINALCANAL': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C00023C750> >,
#  'TRACHEA': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x000001C00023C7B0> >}

# %%
vis = ImageVisualiser(img_ct_lung_10, cut=(50,256,256))
vis.add_contour(contours)
fig = vis.show()

# %%
ctr = sitk.ReadImage("./PRHGD5257_LUNG/STRUCTURES/PRHGD5257_LUNG_2_RTSTRUCT_4TH_RIB.nii.gz")

# %%
vis.add_contour(ctr, color="green", linewidth=3)
fig = vis.show()
